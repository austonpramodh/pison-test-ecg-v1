# %%
import numpy as np
import pandas as pd 
import os
import random
from tqdm import tqdm
import matplotlib
import seaborn as sns
import matplotlib.pyplot as plt
# import plotly.graph_objs as go
# from plotly.offline import init_notebook_mode, iplot
# from plotly import tools
from scipy.stats import mannwhitneyu

# init_notebook_mode(connected=True) ## plotly init
seed = 123
random.seed = seed

# %%
filenames_list = os.listdir('./data') ## list of file names in the directory
EEG_data = pd.DataFrame({}) ## create an empty df that will hold data from each file

for file_name in tqdm(filenames_list):
    temp_df = pd.read_csv('./data/' + file_name) ## read from the file to df
    EEG_data = EEG_data.append(temp_df) ## add the file data to the main df
    
EEG_data = EEG_data.drop(['Unnamed: 0'], axis=1) ## remove the unused column
EEG_data.loc[EEG_data['matching condition'] == 'S2 nomatch,', 'matching condition'] =  'S2 nomatch' ## remove comma sign from stimulus name
# Out:
#   0%|          | 0/480 [00:00<?, ?it/s]C:\Users\austo\AppData\Local\Temp\ipykernel_7044\844495895.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   EEG_data = EEG_data.append(temp_df) ## add the file data to the main df
# C:\Users\austo\AppData\Local\Temp\ipykernel_7044\844495895.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   EEG_data = EEG_data.append(temp_df) ## add the file data to the main df
# C:\Users\austo\AppData\Local\Temp\ipykernel_7044\844495895.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   EEG_data = EEG_data.append(temp_df) ## add the file data to the main df
# ...

# %%
## here is how the data looks like
EEG_data.head()
# Out:
#    trial number sensor position  sample num  sensor value subject identifier  \
# 0            30             FP1           0        -3.550                  a
# 1            30             FP1           1        -5.015                  a
# 2            30             FP1           2        -5.503                  a
# 3            30             FP1           3        -3.550                  a
# 4            30             FP1           4        -0.621                  a
#
#   matching condition  channel         name      time
# 0             S1 obj        0  co2a0000364  0.000000
# 1             S1 obj        0  co2a0000364  0.003906
# 2             S1 obj        0  co2a0000364  0.007812
# 3             S1 obj        0  co2a0000364  0.011719
# 4             S1 obj        0  co2a0000364  0.015625

# %%
# export the data to json file
df = EEG_data.copy()
df.reset_index(inplace=True)
df.to_json('./EEG_data.json', orient='records')

# %% [markdown]
# # V2 dataset ----

# %%
import pandas as pd
import numpy as np

df = pd.read_csv('./ecg.csv', header=None)

df.head()
# Out:
#         0         1         2         3         4         5         6    \
# 0 -0.112522 -2.827204 -3.773897 -4.349751 -4.376041 -3.474986 -2.181408
# 1 -1.100878 -3.996840 -4.285843 -4.506579 -4.022377 -3.234368 -1.566126
# 2 -0.567088 -2.593450 -3.874230 -4.584095 -4.187449 -3.151462 -1.742940
# 3  0.490473 -1.914407 -3.616364 -4.318823 -4.268016 -3.881110 -2.993280
# 4  0.800232 -0.874252 -2.384761 -3.973292 -4.338224 -3.802422 -2.534510
#
#         7         8         9    ...       131       132       133       134  \
# 0 -1.818286 -1.250522 -0.477492  ...  0.792168  0.933541  0.796958  0.578621
# 1 -0.992258 -0.754680  0.042321  ...  0.538356  0.656881  0.787490  0.724046
# 2 -1.490659 -1.183580 -0.394229  ...  0.886073  0.531452  0.311377 -0.021919
# 3 -1.671131 -1.333884 -0.965629  ...  0.350816  0.499111  0.600345  0.842069
# 4 -1.783423 -1.594450 -0.753199  ...  1.148884  0.958434  1.059025  1.371682
#
#         135       136       137       138       139  140
# ...

# %%
# Add column names as lead<index> 
df.columns = ['lead' + str(i) for i in range(df.shape[1])]
# rename the last columnt to 'label'
df.rename(columns={'lead' + str(df.shape[1] - 1): 'label'}, inplace=True)
# Add a column with arbitrary heart rate values
df['hr'] = np.random.randint(60, 100, df.shape[0])

# %%
df.head()
# Out:
#       lead0     lead1     lead2     lead3     lead4     lead5     lead6  \
# 0 -0.112522 -2.827204 -3.773897 -4.349751 -4.376041 -3.474986 -2.181408
# 1 -1.100878 -3.996840 -4.285843 -4.506579 -4.022377 -3.234368 -1.566126
# 2 -0.567088 -2.593450 -3.874230 -4.584095 -4.187449 -3.151462 -1.742940
# 3  0.490473 -1.914407 -3.616364 -4.318823 -4.268016 -3.881110 -2.993280
# 4  0.800232 -0.874252 -2.384761 -3.973292 -4.338224 -3.802422 -2.534510
#
#       lead7     lead8     lead9  ...   lead132   lead133   lead134   lead135  \
# 0 -1.818286 -1.250522 -0.477492  ...  0.933541  0.796958  0.578621  0.257740
# 1 -0.992258 -0.754680  0.042321  ...  0.656881  0.787490  0.724046  0.555784
# 2 -1.490659 -1.183580 -0.394229  ...  0.531452  0.311377 -0.021919 -0.713683
# 3 -1.671131 -1.333884 -0.965629  ...  0.499111  0.600345  0.842069  0.952074
# 4 -1.783423 -1.594450 -0.753199  ...  0.958434  1.059025  1.371682  1.277392
#
#     lead136   lead137   lead138   lead139  label  hr
# ...

# %%
# convert to json
df.to_json('./ecg.json', orient='records')

# %%
signal = df.iloc[np.random.randint(0, len(df))].to_list()

# %%
signal
# Out:
# [0.47189179,
#  -0.41881547,
#  -1.4809334,
#  -2.4265612,
#  -3.1833606,
#  -3.5059373,
#  -3.4340577,
#  -2.9802224,
#  -2.3706542,
#  -1.7901487,
#  -1.3633933,
#  -1.2292165,
#  -0.85186995,
#  -0.30126025,
#  -0.13435093,
#  -0.14982002,
#  -0.12355055,
#  -0.15781105,
#  -0.14184137,
#  -0.15678848,
#  -0.045339848,
#  -0.096420098,
#  -0.14356894,
#  -0.11924723,
#  -0.15053365,
#  -0.16746548,
#  -0.13596483,
#  -0.15906001,
#  -0.16161994,
#  -0.26086879,
#  -0.17356847,
#  -0.16488344,
#  -0.31284169,
#  -0.27302881,
#  -0.24748463,
#  -0.27389653,
#  -0.33170432,
#  -0.2917571,
#  -0.33639247,
#  -0.33174172,
#  -0.35184748,
#  -0.31690531,
#  -0.30497539,
#  -0.37036249,
#  -0.35830353,
#  -0.44991342,
#  -0.45972045,
#  -0.52870965,
#  -0.55766098,
#  -0.55916222,
#  -0.62332648,
#  -0.61175579,
#  -0.62558806,
#  -0.64859284,
#  -0.68770078,
#  -0.72349272,
#  -0.73125133,
#  -0.7401418,
#  -0.77150596,
#  -0.71210457,
#  -0.69666857,
#  -0.69786946,
#  -0.66010016,
# ...
